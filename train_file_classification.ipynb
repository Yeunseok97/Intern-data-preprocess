# %%
import random
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image, ImageDraw, ImageFont, ImageOps
from tqdm import tqdm

# %%
import yaml
data = {'train': "/home/selectstar/yolov5/dataset/File_classification/train",
        "val": "/home/selectstar/yolov5/dataset/File_classification/valid",
        "nc": 1,
        "names": ['file']}

with open("select_Star2.yaml", "w") as f:
    yaml.dump(data, f)

# %%
# !python3 train.py --data /home/selectstar/yolov5/select_Star.yaml --hyp /home/selectstar/yolov5/data/hyps/hyp.scratch-high.yaml --device 1 --cos-lr --patience 10 --batch-size 32 --label-smoothing 0.1 --workers 0 --epochs 120 --project File_extraction --name star_pjt --cfg /home/selectstar/yolov5/models/yolov5m.yaml

# %%
# !python3 train.py --data /home/selectstar/yolov5/select_Star.yaml --hyp /home/selectstar/yolov5/data/hyps/hyp.scratch-high.yaml --device 1 --cos-lr --patience 50 --batch-size 32 --label-smoothing 0.1 --workers 0 --epochs 130 --project File_extraction --name star_pjt --cfg /home/selectstar/yolov5/models/yolov5m.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-07-17 15:33:05.012153: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-17 15:33:05.012257: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-17 15:33:05.012310: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: yeunseok. Use `wandb login --relogin` to force relogin
# ...

# %%
import random
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image, ImageDraw, ImageFont, ImageOps
from tqdm import tqdm

# !python3 train.py --data /home/selectstar/yolov5/select_Star.yaml --hyp /home/selectstar/yolov5/data/hyps/hyp.scratch-high.yaml --device 1 --cos-lr --patience 50 --batch-size 32 --label-smoothing 0.1 --workers 0 --epochs 150 --project File_extraction --name star_pjt --cfg /home/selectstar/yolov5/models/yolov5m.yaml
