# %%
import random
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image, ImageDraw, ImageFont, ImageOps
from tqdm import tqdm

# %%
import yaml
data = {'train': "/home/selectstar/yolov5/dataset/Table_classification/train",
        "val": "/home/selectstar/yolov5/dataset/Table_classification/valid",
        "nc": 6,
        "names": ['Table', 'Text1', 'Text2','Info', 'Picture','Text_box']}

with open("select_Star.yaml", "w") as f:
    yaml.dump(data, f)

# %%
# !python3 train.py --data /home/selectstar/yolov5/select_Star.yaml --hyp /home/selectstar/yolov5/data/hyps/hyp.scratch-high.yaml --device 1 --cos-lr --patience 10 --batch-size 32 --label-smoothing 0.1 --workers 0 --epochs 60 --project Table_extraction --name star_pjt --cfg /home/selectstar/yolov5/models/yolov5m.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-07-10 02:02:46.935819: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-10 02:02:46.935925: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-10 02:02:46.935982: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: yeunseok. Use `wandb login --relogin` to force relogin
# ...

# %%
pwd
# Out:
# '/home/selectstar/yolov5'

# %%
# detection 수행하는 부분 디렉토리 내 전체 탐지
# 이 부분은 가볍게 detection 결과와 crop된 이미지가 잘 저장되는 지 확인하는 부분이다.
# !python3 detect.py --weights /home/selectstar/yolov5/Table_extraction/star_pjt/weights/best.pt --source /home/selectstar/yolov5/dataset/Table_classification/test/ --save-crop --device 1
